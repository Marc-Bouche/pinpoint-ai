# %% [markdown]
# # <span style="color:red">**PinpointAI**</span>

# %% [markdown]
# ## ***Notes***

# %%
# IP Geolocation API (1000 calls per day max)
# https://app.abstractapi.com/api/ip-geolocation/tester

# %%
import pandas as pd
import requests

# Specify the path to your Excel file
file_path = '/Users/mbouch17/Desktop/Personal_Data_Project/PinpointAI/worldcities.csv'

# Import the Excel file
df_ww = pd.read_csv(file_path)

# Display the first few rows of the dataframe
df_ww.head()
# Out:
#         city city_ascii      lat       lng    country iso2 iso3   admin_name  \
# 0      Tokyo      Tokyo  35.6897  139.6922      Japan   JP  JPN        Tōkyō
# 1    Jakarta    Jakarta  -6.1750  106.8275  Indonesia   ID  IDN      Jakarta
# 2      Delhi      Delhi  28.6100   77.2300      India   IN  IND        Delhi
# 3  Guangzhou  Guangzhou  23.1300  113.2600      China   CN  CHN    Guangdong
# 4     Mumbai     Mumbai  19.0761   72.8775      India   IN  IND  Mahārāshtra
#
#    capital  population          id
# 0  primary  37732000.0  1392685764
# 1  primary  33756000.0  1360771077
# 2    admin  32226000.0  1356872604
# 3    admin  26940000.0  1156237133
# 4    admin  24973000.0  1356226629

# %%
df_ww.shape
# Out:
# (47868, 11)

# %%
df_ww.isnull().sum()
# Out:
# city              0
# city_ascii        1
# lat               0
# lng               0
# country           0
# iso2             33
# iso3              0
# admin_name      197
# capital       34845
# population      212
# id                0
# dtype: int64

# %% [markdown]
# ## *List of  Data Frames*

# %%
# df_images
# Store google image streetview based on coordinates

# %%
# df_ww
# Public csv file : Store WW cities coordinates

# %%
# df_fr
# Public csv file : Store FR cities coordinates

# %%
# df_coordinates1
# Store 1000 random coordinates from all random streetview location in France, Andorra, Luxemburg. Also include parts of Italy, Spain, Germany, 90% of Switzerland, 80% of Belgium and  a small section of Netherlands

# %%
# df_coordinates2 (WIP)
# Same purpose as df_coordinates1

# %%
df_coordinates3.head()
# Out:
#     Latitude  Longitude
# 0  48.502933   9.170228
# 1  45.541638   1.524269
# 2  47.072288   3.040149
# 3  44.900643   8.063164
# 4  49.360638   6.186067

# %%
df_coordinates2.head()
# Out:
#     Latitude  Longitude
# 0  48.539645   7.677287
# 1  49.660573   0.162917
# 2  43.301026  -2.994311
# 3  50.148928   1.821579
# 4  47.074279   2.354251

# %%
df_coordinates1.head()
# Out:
#     Latitude  Longitude
# 0  48.451138   8.643300
# 1  50.775667  -3.407368
# 2  46.932466   2.118208
# 3  45.611479   3.715073
# 4  42.212476  -2.238536

# %% [markdown]
# ## **1. Getting Random Coordinates in France**

# %%
# Filter the DataFrame for rows where 'iso2' is 'FR'
df_fr = df_ww[df_ww['iso2'] == 'FR']

# Display the new DataFrame
df_fr
# Out:
#                    city        city_ascii      lat     lng country iso2 iso3  \
# 36                Paris             Paris  48.8567  2.3522  France   FR  FRA
# 775            Bordeaux          Bordeaux  44.8400 -0.5800  France   FR  FRA
# 884           Marseille         Marseille  43.2964  5.3700  France   FR  FRA
# 1416               Lyon              Lyon  45.7600  4.8400  France   FR  FRA
# 1462           Toulouse          Toulouse  43.6045  1.4440  France   FR  FRA
# ...                 ...               ...      ...     ...     ...  ...  ...
# 46330        Pérenchies        Perenchies  50.6686  2.9731  France   FR  FRA
# 46352  Thaon-les-Vosges  Thaon-les-Vosges  48.2510  6.4200  France   FR  FRA
# 46356           Sautron           Sautron  47.2644 -1.6667  France   FR  FRA
# 46373            Liffré            Liffre  48.2142 -1.5067  France   FR  FRA
# 46390     Saint-Vallier     Saint-Vallier  46.6428  4.3719  France   FR  FRA
#
# ...

# %%
df_images.head()
# Out:
#      image_filename  latitude  longitude       city
# 0  streetview_0.jpg   48.8567     2.3522      Paris
# 1  streetview_1.jpg   44.8400    -0.5800   Bordeaux
# 2  streetview_2.jpg   43.2964     5.3700  Marseille
# 3  streetview_3.jpg   45.7600     4.8400       Lyon
# 4  streetview_4.jpg   43.6045     1.4440   Toulouse

# %% [raw]
# # This code uses a square as a reference which overlap on France border countries such as Spain, Germany, Italy, etc.
#
# import requests
# import random
# import time
# import pandas as pd  # Import pandas to create a DataFrame
#
# # Set up API Keys
# STREET_VIEW_API_KEY = "*************************"  # Replace with your Google Street View API Key
# num_coordinates = 1000  # We want to fetch 1000 coordinates
#
# # France's bounding box (latitude, longitude)
# lat_min = 41.3039
# lat_max = 51.1242
# lon_min = -5.325
# lon_max = 9.6625
#
# # Function to generate random coordinates within the bounding box of France
# def generate_random_coordinate():
#     lat = random.uniform(lat_min, lat_max)
#     lon = random.uniform(lon_min, lon_max)
#     return lat, lon
#
# # Function to check if a location has Google Street View coverage
# def check_streetview_coverage(lat, lon):
#     url = f"https://maps.googleapis.com/maps/api/streetview/metadata?location={lat},{lon}&key={STREET_VIEW_API_KEY}"
#     response = requests.get(url)
#     if response.status_code == 200:
#         data = response.json()
#         return data.get("status") == "OK"
#     return False
#
# # List to store valid coordinates with Street View coverage
# valid_coordinates = []
#
# # Loop until we collect 1000 valid coordinates
# while len(valid_coordinates) < num_coordinates:
#     lat, lon = generate_random_coordinate()
#     if check_streetview_coverage(lat, lon):
#         valid_coordinates.append((lat, lon))
#         print(f"Added valid coordinate: ({lat}, {lon})")
#
#     # Sleep to prevent hitting API rate limits (adjust as needed)
#     time.sleep(0.1)  # Reduce sleep time if your API allows higher frequency calls
#
# # After the loop, valid_coordinates will contain the 1000 coordinates with Street View coverage
# print(f"Successfully collected {len(valid_coordinates)} coordinates with Street View coverage.")
#
# # Store the coordinates in a pandas DataFrame
# df_coordinates4 = pd.DataFrame(valid_coordinates, columns=["Latitude", "Longitude"])
#
# # Optionally, save the DataFrame to a CSV file
# df_coordinates4.to_csv("valid_coordinates.csv", index=False)
#
# # Print the first few rows of the DataFrame for verification
# print(df_coordinates4.head())

# %%
import requests
import random
import time
import pandas as pd  # Import pandas to create a DataFrame
import geopandas as gpd  # Import geopandas for geospatial data processing

# Set up API Keys
STREET_VIEW_API_KEY = "AIzaSyDugvJ210sXsrpBIRtR7B2tIsNNcFiJjqk"  # Replace with your Google Street View API Key
num_coordinates = 6990  # Number of coordinates to generate

# Load the France boundary from the JSON file (GeoJSON format)
france_gdf = gpd.read_file('/Users/mbouch17/Desktop/Personal_Data_Project/PinpointAI/france.json')  # Corrected path

# Function to generate random coordinates within the bounding box of France
def generate_random_coordinate():
    # Get the bounding box of the France polygon
    minx, miny, maxx, maxy = france_gdf.bounds.values[0]
    lat = random.uniform(miny, maxy)
    lon = random.uniform(minx, maxx)
    return lat, lon

# Function to check if a location has Google Street View coverage
def check_streetview_coverage(lat, lon):
    url = f"https://maps.googleapis.com/maps/api/streetview/metadata?location={lat},{lon}&key={STREET_VIEW_API_KEY}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        print(f"Response for {lat}, {lon}: {data['status']}")  # Debug print
        return data.get("status") == "OK"
    print(f"Failed request for {lat}, {lon}, status code: {response.status_code}")  # Debug if request fails
    return False

# List to store valid coordinates with Street View coverage
valid_coordinates = []

# Loop until we collect 5000 valid coordinates (or more)
while len(valid_coordinates) < num_coordinates:
    lat, lon = generate_random_coordinate()
    print(f"Generated coordinate: ({lat}, {lon})")  # Debug print for each generated coordinate
    if check_streetview_coverage(lat, lon):
        valid_coordinates.append((lat, lon))
        print(f"Added valid coordinate: ({lat}, {lon})")

    # Sleep to prevent hitting API rate limits (adjust as needed)
    time.sleep(0.1)  # Reduce sleep time if your API allows higher frequency calls

# After the loop, valid_coordinates will contain the valid coordinates with Street View coverage
print(f"Successfully collected {len(valid_coordinates)} coordinates with Street View coverage.")

# Store the coordinates in a pandas DataFrame
df_coordinates_fr7 = pd.DataFrame(valid_coordinates, columns=["Latitude", "Longitude"])

# Optionally, save the DataFrame to a CSV file
df_coordinates_fr7.to_csv("valid_coordinates_fr7.csv", index=False)

# Print the first few rows of the DataFrame for verification
print(df_coordinates_fr7.head())
# Out:
# Generated coordinate: (46.39156865262062, -1.869244206994976)
# Response for 46.39156865262062, -1.869244206994976: ZERO_RESULTS
# Generated coordinate: (44.67218562970552, 3.145519243543321)
# Response for 44.67218562970552, 3.145519243543321: ZERO_RESULTS
# Generated coordinate: (48.303201076950145, -2.730415986577303)
# Response for 48.303201076950145, -2.730415986577303: ZERO_RESULTS
# Generated coordinate: (42.892337080891664, 6.841027355624668)
# Response for 42.892337080891664, 6.841027355624668: ZERO_RESULTS
# Generated coordinate: (50.63198402699622, -0.38569424765415317)
# Response for 50.63198402699622, -0.38569424765415317: ZERO_RESULTS
# Generated coordinate: (50.34975699542742, 1.2599728240656098)
# Response for 50.34975699542742, 1.2599728240656098: ZERO_RESULTS
# Generated coordinate: (50.83572223146575, 2.453107087864285)
# Response for 50.83572223146575, 2.453107087864285: ZERO_RESULTS
# Generated coordinate: (50.25712321765179, 4.404532581102016)
# ...

# %%
df_coordinates_fr7.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df_coordinates_fr7.shape
#
# NameError: name 'df_coordinates_fr7' is not defined
